# %% [markdown]
# # Carga de datos capturados con el OZM

# %% [markdown]
# ## Primeros analisis de cargas de datos ¶
# En primer lugar, se analizan metadatos y datos del dataset cuya estructura deberia basarse en el formato NILMTK-DF.
#
# Contemos el numero de filas de cada fichero de datos en el nuevo formato parquet

# %%
import pandas as pd
import os
import numpy as np

# %%
def modulus(val):
    """
    get modulus of a complex number
    """
    res_val = []
    #print('modulus')
    if (isinstance(val, list)):
        for i in range(len(val)):
            val_item = val[i]
            #print (val_item) 
            if isinstance(val_item, list):
                if(len(val_item) == 2):
                    res = np.sqrt(val_item[0]**2 + val_item[1]**2)
                    val_item = res
            res_val.append(val_item)
            #print(res_val)
    else:
        res_val = val
        #print (res_val)
    return res_val

def array_to_list(array):
    """Convert numpy array to list"""
    if isinstance(array, np.ndarray):
        return array_to_list(array.tolist())
    elif isinstance(array, list):
        return [array_to_list(item) for item in array]
    elif isinstance(array, tuple):
        return tuple(array_to_list(item) for item in array)
    else:
        return array

# %% [markdown]
# ## leer un fichero de datos

# %%
df_path = ".\data\ozm1\ozm_fan_200MS.parquet"
print(os.path.exists(df_path))
print(os.getcwd())
df = pd.read_parquet(df_path)
item = df.iloc[0]['Voltage_Harmonics_Complex']
print(item)
print(type(item))
# Out:
# True
# C:\Users\carlo\jupyter_notebooks\experimentos Marzo 2023\ozm_datos_completos _noviembre2_ESTADOS_UNICOS -TRANSITORIOS
# [array([-25.4815, 245.372 ]) array([0.089041, 0.141629])
#  array([-1.0736 , -1.62738]) array([0.014393, 0.06979 ])
#  array([ 0.389849, -2.87408 ]) array([-0.018005, -0.001233])
#  array([-3.15549 ,  0.862872]) array([-0.005918,  0.041427])
#  array([ 0.146057, -2.22932 ]) array([-0.004639,  0.044318])
#  array([-0.14173 ,  0.295629]) array([-0.012614,  0.005815])
#  array([0.051997, 0.596652]) array([-0.011123,  0.000507])
#  array([0.128908, 0.02895 ]) array([0.000583, 0.006063])
#  array([-0.263489, -0.074059]) array([0.001006, 0.006622])
#  array([-0.127894, -0.024463]) array([-0.003756,  0.001148])
#  array([0.025738, 0.01027 ]) array([0.000312, 0.010101])
#  array([0.011124, 0.055558]) array([-0.005105,  0.018317])
#  array([ 0.063779, -0.092359]) array([-2.33e-03, -2.20e-05])
#  array([0.049343, 0.017603]) array([-0.002216,  0.002918])
#  array([-0.056977,  0.027195]) array([-0.00098,  0.01177])
#  array([-0.052599,  0.025109]) array([-0.009991,  0.009401])
#  array([-0.019689,  0.030066]) array([-0.005188,  0.007417])
#  array([-0.006294, -0.046142]) array([-0.002549,  0.003532])
#  array([ 0.004352, -0.076297]) array([-0.000123, -0.00306 ])
#  array([ 0.002901, -0.001856]) array([-0.011301,  0.00077 ])
#  array([-0.00905 , -0.017625]) array([0.005051, 0.009666])
#  array([0.003316, 0.002466]) array([-0.010537,  0.004318])
#  array([0.000961, 0.002212]) array([ 0.001324, -0.000441])
#  array([ 0.000976, -0.001073]) array([-0.00514 , -0.000706])
#  array([ 0.000588, -0.012868]) array([0.001267, 0.005078])]
# <class 'numpy.ndarray'>

# %% [markdown]
# 0        [239.95425926196853, 3.3079093001169184, 2.701...
# 1        [242.12684891868145, 1.5281954031615197, 1.084...
# 2        [242.5702061057994, 0.2218705199209665, 1.8971...
# 3        [242.50256694082643, 0.14188803530248772, 2.03...
# 4        [242.53347239059602, 0.01846863841759863, 1.98...
#                                ...
# 39403    [244.75933004190054, 0.32007489714908915, 1.89...
# 39404    [244.6773134517379, 0.05796792183613278, 2.032...
# 39405    [244.65726304248562, 0.02422492010306742, 2.00...
# 39406    [244.6480277329249, 0.015282713404366387, 1.99...
# 39407    [244.4975795552177, 0.2887791588272949, 2.1860...

# %% [markdown]
# ## Convertir el array en una lista

# %%
df = df.applymap(array_to_list)
item = df.iloc[0]['Voltage_Harmonics_Complex']
print(item)
print(type(item))
# Out:
# [[-25.4815, 245.372], [0.089041, 0.141629], [-1.0736, -1.62738], [0.014393, 0.06979], [0.389849, -2.87408], [-0.018005, -0.001233], [-3.15549, 0.862872], [-0.005918, 0.041427], [0.146057, -2.22932], [-0.004639, 0.044318], [-0.14173, 0.295629], [-0.012614, 0.005815], [0.051997, 0.596652], [-0.011123, 0.000507], [0.128908, 0.02895], [0.000583, 0.006063], [-0.263489, -0.074059], [0.001006, 0.006622], [-0.127894, -0.024463], [-0.003756, 0.001148], [0.025738, 0.01027], [0.000312, 0.010101], [0.011124, 0.055558], [-0.005105, 0.018317], [0.063779, -0.092359], [-0.00233, -2.2e-05], [0.049343, 0.017603], [-0.002216, 0.002918], [-0.056977, 0.027195], [-0.00098, 0.01177], [-0.052599, 0.025109], [-0.009991, 0.009401], [-0.019689, 0.030066], [-0.005188, 0.007417], [-0.006294, -0.046142], [-0.002549, 0.003532], [0.004352, -0.076297], [-0.000123, -0.00306], [0.002901, -0.001856], [-0.011301, 0.00077], [-0.00905, -0.017625], [0.005051, 0.009666], [0.003316, 0.002466], [-0.010537, 0.004318], [0.000961, 0.002212], [0.001324, -0.000441], [0.000976, -0.001073], [-0.00514, -0.000706], [0.000588, -0.012868], [0.001267, 0.005078]]
# <class 'list'>

# %% [markdown]
# ## Calcular el modulo de todas las partes complejas para el campo voltaje

# %%
df = df.applymap(modulus)
item = df.iloc[0]['Voltage_Harmonics_Complex']
print(item)
print(type(item))
# Out:
# [246.6915588873077, 0.16729337500929317, 1.9496108905112324, 0.07125870156689638, 2.900399643014907, 0.018047169140892983, 3.2713399744575615, 0.041847569260352505, 2.2340994404119527, 0.04456013291048402, 0.32784737080080417, 0.01388982436894002, 0.5989134303995862, 0.011134548845822177, 0.132118791108608, 0.006090965276538686, 0.27369908403573434, 0.0066979787996081334, 0.1302125708409138, 0.003927523392673811, 0.027711325193862525, 0.01010581738406152, 0.05666069837197562, 0.019015086484157784, 0.11224057074872704, 0.0023301038603461433, 0.05238890395875829, 0.0036640660474396474, 0.06313435320013978, 0.01181072817399503, 0.05828478945659837, 0.013718559764056866, 0.03593913016476609, 0.009051366360942418, 0.046569288162908395, 0.004355734725623221, 0.07642101879064424, 0.0030624710610877614, 0.0034439130360681292, 0.011327201816865452, 0.019812701103080317, 0.010906152254576312, 0.004132434149505591, 0.011387426970128062, 0.0024117348527564137, 0.0013955131672614201, 0.0014504844018465002, 0.005188259438385864, 0.012881427250114794, 0.005233676814630418]
# <class 'list'>

# %% [markdown]
# ## Comprobacion de numero de filas para cada fichero

# %%
with open(r'.\data\ozm1\ozm_fan_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero freezer=',len(df.index))
# Out:
# filas fichero freezer= 36476

# %%
with open(r'.\data\ozm1\ozm_freezer_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero freezer=',len(df.index))
# Out:
# filas fichero freezer= 36477

# %%
with open(r'.\data\ozm1\ozm_fridge_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero fridge=',len(df.index))
# Out:
# filas fichero fridge= 36477

# %%
with open(r'.\data\ozm1\ozm_kettle_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero kettle=',len(df.index))
# Out:
# filas fichero kettle= 36494

# %%
with open(r'.\data\ozm1\ozm_microvawe_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero microwave=',len(df.index))
# Out:
# filas fichero microwave= 36494

# %%
with open(r'.\data\ozm1\ozm_monitor_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero monitor=',len(df.index))
# Out:
# filas fichero monitor= 36494

# %%
with open(r'.\data\ozm1\ozm_oil_heater_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero oil_heater=',len(df.index))
# Out:
# filas fichero oil_heater= 36494

# %%
with open(r'.\data\ozm1\ozm_oven_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero oven=',len(df.index))
# Out:
# filas fichero oven= 36494

# %%
with open(r'.\data\ozm1\ozm_vacuum_cleaner_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero vacuum cleaner=',len(df.index))
# Out:
# filas fichero vacuum cleaner= 36494

# %%
with open(r'.\data\ozm1\ozm_water_heater_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero water_heater=',len(df.index))
# Out:
# filas fichero water_heater= 36477

# %%
with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero agregation=',len(df_datos_agregados.index))
# Out:
# filas fichero agregation= 36494

# %% [markdown]
# Las primeras N filas del dataFrame se puede visualizar de la siguiente forma

# %%
N=4
df_datos_agregados.head(N)
# Out:
#      Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage   Current  \
# 0  start   1678183838073      1678183868044  1678183838073  247.147  0.142013
# 1  start   1678183838073      1678183868044  1678183838273  247.202  0.143942
# 2  start   1678183838073      1678183868044  1678183838473  247.190  0.153028
# 3  start   1678183838073      1678183868044  1678183838673  247.137  0.148763
#
#    Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 0    49.9944     0          0      0.629637  18.8298       22.0991
# 1    49.9942     0          0      0.632288  19.4552       22.4985
# 2    49.9942     0          0      0.624243  18.8179       23.6133
# 3    49.9940     0          0      0.623314  19.0161       22.9160
#
#    Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 0        -7.54384       23.351248      297.623      3.70302
# 1        -7.95450       23.863322      305.911      3.71142
# 2        -8.05194       24.948382      317.283      3.71310
# 3        -7.90510       24.241202      311.150      3.65417
#
#                                      Power_Harmonics  \
# 0  [22.1221, 0.000468, 0.023443, -2.9e-05, -0.036...
# 1  [22.5188, -0.000179, 0.022105, 0.000151, -0.03...
# 2  [23.6282, -0.000551, 0.020859, 0.000143, -0.03...
# 3  [22.9371, -8.3e-05, 0.022485, 9e-05, -0.037093...
#
#                            Voltage_Harmonics_Complex  \
# 0  [[22.9884, -246.015], [-0.001805, 0.07656], [1...
# 1  [[23.6718, -246.006], [0.060496, -0.093363], [...
# 2  [[22.5654, -246.098], [-0.046821, -0.089469], ...
# 3  [[23.3384, -245.973], [-0.02625, 0.003081], [1...
#
#                            Current_Harmonics_Complex
# 0  [[0.038729, -0.086303], [0.003932, 0.006209], ...
# 1  [[0.040765, -0.087615], [0.004175, 0.004619], ...
# 2  [[0.041176, -0.092236], [0.002784, 0.004698], ...
# 3  [[0.04062, -0.089397], [0.003748, 0.005119], [...

# %% [markdown]
# Y las N últimas filas

# %%
df_datos_agregados.tail(N)
# Out:
#        Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage  \
# 36490  end   1678191104593      1678191135486  1678191134791  248.716
# 36491  end   1678191104593      1678191135486  1678191134991  248.676
# 36492  end   1678191104593      1678191135486  1678191135191  248.630
# 36493  end   1678191104593      1678191135486  1678191135391  248.578
#
#         Current  Frequency  Flag  Unbalance  Power_Factor      Phi  \
# 36490  0.132425    49.9896     0          0      0.554462  20.6644
# 36491  0.129423    49.9894     0          0      0.549108  19.6061
# 36492  0.128296    49.9894     0          0      0.555321  20.6193
# 36493  0.127680    49.9890     0          0      0.549747  21.0327
#
#        Active_Power  Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 36490       18.2619        -6.86620       19.510054      448.193      4.18314
# 36491       17.6728        -6.27814       18.754765      450.616      4.22112
# 36492       17.7137        -6.64853       18.920320      443.094      4.17896
# 36493       17.4481        -6.69050       18.686859      441.336      4.25438
#
#                                          Power_Harmonics  \
# 36490  [18.2051, 1.6e-05, 0.034377, -0.000219, 0.0373...
# 36491  [17.6251, -0.0004, 0.032079, -0.000138, 0.0309...
# 36492  [17.67, -0.000474, 0.03218, -6.3e-05, 0.029577...
# 36493  [17.3997, 0.000256, 0.036514, -0.000401, 0.031...
#
#                                Voltage_Harmonics_Complex  \
# 36490  [[21.4808, -247.7], [4.3e-05, 0.002468], [0.70...
# 36491  [[21.6877, -247.64], [-0.050326, -0.055171], [...
# 36492  [[20.9179, -247.661], [0.021761, -0.076675], [...
# 36493  [[21.4755, -247.557], [-0.052345, 0.076959], [...
#
#                                Current_Harmonics_Complex
# 36490  [[0.033839, -0.070562], [0.003583, 0.006392], ...
# 36491  [[0.031345, -0.068427], [0.004034, 0.003577], ...
# 36492  [[0.032639, -0.068591], [0.003945, 0.0073], [-...
# 36493  [[0.032876, -0.067433], [0.003476, 0.005692], ...

# %% [markdown]
# Filtrar por un determinado valor

# %%
df_datos_agregados[df_datos_agregados.Unbalance ==0 ].head()
# Out:
#      Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage   Current  \
# 0  start   1678183838073      1678183868044  1678183838073  247.147  0.142013
# 1  start   1678183838073      1678183868044  1678183838273  247.202  0.143942
# 2  start   1678183838073      1678183868044  1678183838473  247.190  0.153028
# 3  start   1678183838073      1678183868044  1678183838673  247.137  0.148763
# 4  start   1678183838073      1678183868044  1678183838873  247.172  0.177928
#
#    Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 0    49.9944     0          0      0.629637  18.8298       22.0991
# 1    49.9942     0          0      0.632288  19.4552       22.4985
# 2    49.9942     0          0      0.624243  18.8179       23.6133
# 3    49.9940     0          0      0.623314  19.0161       22.9160
# 4    49.9940     0          0      0.574146  17.2776       25.2503
#
#    Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 0        -7.54384       23.351248      297.623      3.70302
# 1        -7.95450       23.863322      305.911      3.71142
# 2        -8.05194       24.948382      317.283      3.71310
# 3        -7.90510       24.241202      311.150      3.65417
# 4        -7.85989       26.445364      419.074      3.66096
#
#                                      Power_Harmonics  \
# 0  [22.1221, 0.000468, 0.023443, -2.9e-05, -0.036...
# 1  [22.5188, -0.000179, 0.022105, 0.000151, -0.03...
# 2  [23.6282, -0.000551, 0.020859, 0.000143, -0.03...
# 3  [22.9371, -8.3e-05, 0.022485, 9e-05, -0.037093...
# 4  [25.27, -0.001055, 0.024908, 0.000355, -0.0402...
#
#                            Voltage_Harmonics_Complex  \
# 0  [[22.9884, -246.015], [-0.001805, 0.07656], [1...
# 1  [[23.6718, -246.006], [0.060496, -0.093363], [...
# 2  [[22.5654, -246.098], [-0.046821, -0.089469], ...
# 3  [[23.3384, -245.973], [-0.02625, 0.003081], [1...
# 4  [[23.9898, -245.946], [-0.059052, -0.051255], ...
#
#                            Current_Harmonics_Complex
# 0  [[0.038729, -0.086303], [0.003932, 0.006209], ...
# 1  [[0.040765, -0.087615], [0.004175, 0.004619], ...
# 2  [[0.041176, -0.092236], [0.002784, 0.004698], ...
# 3  [[0.04062, -0.089397], [0.003748, 0.005119], [...
# 4  [[0.041584, -0.09869], [0.009022, 0.010187], [...

# %% [markdown]
# Filtramos por un valor numerico

# %%
df_datos_agregados[df_datos_agregados.Frequency >=50 ].head()
# Out:
#       Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage  \
# 85  start   1678183838073      1678183868044  1678183855068  247.004
# 86  start   1678183838073      1678183868044  1678183855268  246.935
# 87  start   1678183838073      1678183868044  1678183855467  246.934
# 88  start   1678183838073      1678183868044  1678183855667  246.931
# 89  start   1678183838073      1678183868044  1678183855867  246.990
#
#      Current  Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 85  0.138361    50.0002     0          0      0.627473  18.9997       21.4444
# 86  0.137926    50.0002     0          0      0.633768  17.7942       21.5854
# 87  0.136405    50.0006     0          0      0.628157  19.2638       21.1582
# 88  0.136742    50.0006     0          0      0.639620  17.3772       21.5973
# 89  0.139116    50.0010     0          0      0.607417  18.1723       20.8709
#
#     Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 85        -7.39590       22.683934      305.425      3.62141
# 86        -6.93884       22.673305      318.530      3.65538
# 87        -7.40362       22.416152      307.983      3.63960
# 88        -6.77003       22.633501      303.415      3.65313
# 89        -6.85977       21.969356      332.727      3.63007
#
#                                       Power_Harmonics  \
# 85  [21.4796, 0.000131, 0.020758, -1.5e-05, -0.041...
# 86  [21.6195, -0.000345, 0.022297, 4e-05, -0.04397...
# 87  [21.1843, -0.000355, 0.02352, 5.5e-05, -0.0378...
# 88  [21.6333, 6.7e-05, 0.020669, 1.3e-05, -0.03906...
# 89  [20.8981, -0.00047, 0.020237, -1.8e-05, -0.035...
#
#                             Voltage_Harmonics_Complex  \
# 85  [[25.1921, -245.658], [0.050519, -0.033513], [...
# 86  [[25.5161, -245.555], [-0.025592, -0.051808], ...
# 87  [[25.5262, -245.553], [-0.065767, -0.032003], ...
# 88  [[25.42, -245.561], [0.003103, 0.012843], [1.0...
# 89  [[25.6793, -245.593], [-0.016852, -0.073092], ...
#
#                             Current_Harmonics_Complex
# 85  [[0.038666, -0.083472], [0.006279, 0.005546], ...
# 86  [[0.037007, -0.084198], [0.003462, 0.004944], ...
# 87  [[0.038701, -0.082249], [0.002857, 0.005221], ...
# 88  [[0.0363, -0.08434], [0.003837, 0.004294], [-0...
# 89  [[0.03643, -0.081283], [0.003788, 0.005562], [...

# %% [markdown]
# ### GENERACION DE LOS FICHEROS PREPROCESADOS

# %% [markdown]
# En cada fichero  vamos a calcular la potencia aparente para cada valor de timestamp
#
# Por otro lado tambien necesitamos obtener la parte entera del valor de los armonicos de tension y cortriente  mediante la funcion modulo , por lo que tenemos qeu aplicar esa funcion a los datos del fichero
#
# Asismimo es encesario reorganizar las columnas en el orden acordado en nilmtk
#
#
# En los ficheros de datos no nos es util el valor autoincremental  al no ser una variable electrica . Recordar que este valor es  usado como indice del dataset.
#
# Para ello ,usaremos como indice el valor del timestamp, dado que este valor es biunivoco.
#
# Vamos a reconstruir los ficheros csv eliminando pues ese campo.

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_fan_200MS.parquet

# %%
 
    
    
    
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_fan_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)





#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('fan.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_freezer_200MS.parquet

# %%
 
    
    
    
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_freezer_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('freezer.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_monitor_200MS.parquet

# %%
    
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_monitor_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('monitor.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_vacuum_cleaner_200MS.parquet

# %%
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_vacuum_cleaner_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)


df_reset.to_csv('vacuum_cleaner.csv')

#print (df_reset)
    
#df

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero water_heater.h5

# %%
    
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_water_heater_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)


df_reset.to_csv('water_heater.csv')

#print (df_reset)
    
#df

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_kettle_200MS.parquet

# %%
  
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_kettle_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('kettle.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_fridge_200MS.parquet

# %%
  
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_fridge_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('fridge.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_microvawe_200MS.parquet

# %%
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_microvawe_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('microwave.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_oil_heater_200MS.parquet

# %%
  
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_oil_heater_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)


#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('oil_heater.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_oven_200MS.parquet

# %%
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_oven_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('oven.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero ozm_aggregation_200MS.parquet

# %%
  
import pandas as pd
import glob
import math
import matplotlib.pyplot as plt
import numpy as np
import bokeh
from bokeh.plotting import figure
from bokeh.io import export_png
# select a palette
from bokeh.palettes import Category10




df_path = ".\data\ozm1\ozm_aggregation_200MS.parquet"
#print(os.path.exists(df_path))
#print(os.getcwd())
df = pd.read_parquet(df_path)  #leemos todo el fichero y lo cargamos en un dataframe





# se calcula todo en una sola vez para todo el dataframe
#item = df['Voltage_Harmonics_Complex']  #recupera de la fila 1 el voltaje complejo
#print(item)
#print(type(item))
df = df.applymap(array_to_list)  #crea un dataframe de listas
#item = df['Voltage_Harmonics_Complex']
#print(item)
#print(type(item))
df = df.applymap(modulus) #crea un dataframe con los modulos

#almacenamos el voltaje complejo
item = df['Voltage_Harmonics_Complex']
#print(item)

#almacenamos la corriente compleja
items = df['Current_Harmonics_Complex']
#print(items)


#eliminamos columnas que no vamos a necesitar
df.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Tag'],axis = 'columns', inplace=True)


#insertamos nuevas columnas en el dataframe
df.insert (1,'Voltage_Harmonics_Complex',item)
df.insert (2,'Current_Harmonics_Complex',items)



#renombramos columnas
df.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA' },inplace=True)
df.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)

#eliminamos columnas que no vamos a necesitar
#df.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)

#eliminamos columnas que no vamos a necesitar
df.drop (['FirstTimestamp','OriginalTimestamp'],axis = 'columns', inplace=True)


#df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)

#reordenamos las columnas
df=df [['timestamp','W','VAR','VA','f','VLN','PF','A','Voltage_Harmonics_Complex',  'Current_Harmonics_Complex','Power_Harmonics' ]]

#eliminamos columna indice y la sustituimos por el campo timestamp
df_reset=df.set_index('timestamp')

#print (df_reset)

df_reset.to_csv('aggregation.csv')

# %% [markdown]
# ## Analisis fechas

# %%
import pandas as pd

with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

print ('filas fichero aggregation.hdf5=',len(df_datos_agregados.index))
# Out:
# filas fichero aggregation.hdf5= 36494

# %%
N=1
df_datos_agregados.head(N)
# Out:
#      Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage   Current  \
# 0  start   1678183838073      1678183868044  1678183838073  247.147  0.142013
#
#    Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 0    49.9944     0          0      0.629637  18.8298       22.0991
#
#    Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 0        -7.54384       23.351248      297.623      3.70302
#
#                                      Power_Harmonics  \
# 0  [22.1221, 0.000468, 0.023443, -2.9e-05, -0.036...
#
#                            Voltage_Harmonics_Complex  \
# 0  [[22.9884, -246.015], [-0.001805, 0.07656], [1...
#
#                            Current_Harmonics_Complex
# 0  [[0.038729, -0.086303], [0.003932, 0.006209], ...

# %%
FirstTimestamp=df_datos_agregados.iat[0,1]

# %%
OriginalTimestamp=df_datos_agregados.iat[0,2]

# %%
Time=df_datos_agregados.iat[0,3]

# %%
import pandas as pd
import numpy as np
import datetime
df=pd.DataFrame()

i=[FirstTimestamp,OriginalTimestamp,Time]
df['date']=pd.Series(i)
df['date']=df['date'].apply(lambda d: datetime.datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

df
# Out:
#                   date
# 0  2023-03-07 11:10:38
# 1  2023-03-07 11:11:08
# 2  2023-03-07 11:10:38

# %%
df_datos_agregados.tail(N)
# Out:
#        Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage  \
# 36493  end   1678191104593      1678191135486  1678191135391  248.578
#
#        Current  Frequency  Flag  Unbalance  Power_Factor      Phi  \
# 36493  0.12768     49.989     0          0      0.549747  21.0327
#
#        Active_Power  Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 36493       17.4481         -6.6905       18.686859      441.336      4.25438
#
#                                          Power_Harmonics  \
# 36493  [17.3997, 0.000256, 0.036514, -0.000401, 0.031...
#
#                                Voltage_Harmonics_Complex  \
# 36493  [[21.4755, -247.557], [-0.052345, 0.076959], [...
#
#                                Current_Harmonics_Complex
# 36493  [[0.032876, -0.067433], [0.003476, 0.005692], ...

# %%
FirstTimestamp1=df_datos_agregados.iat[29293,1]

# %%
OriginalTimestamp1=df_datos_agregados.iat[29293,2]

# %%
Time1 =df_datos_agregados.iat[29293,3]

# %%
import pandas as pd
import numpy as np
import datetime
df=pd.DataFrame()

i=[FirstTimestamp1,OriginalTimestamp1,Time1]
df['date']=pd.Series(i)
df['date']=df['date'].apply(lambda d: datetime.datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

df
# Out:
#                   date
# 0  2023-03-07 12:47:36
# 1  2023-03-07 12:49:36
# 2  2023-03-07 12:48:15

# %% [markdown]
# ## Eliminacion de caracteres en fichero csv y localizacion en ruta de conversion

# %% [markdown]
# ### 1- Procesado fichero aggregation.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('aggregation.csv','r') as firstfile, open('./data/ozm1/electricity/1.csv','a') as secondfile: 


with open('aggregation.csv','r') as firstfile, open('aggregation1.csv','a') as secondfile:
    
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
import pandas as pd
import os

datos = pd.read_csv('aggregation1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('aggregation1_2horas.csv', index=False)


datos = pd.read_csv('aggregation1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('aggregation1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('aggregation1.csv')
datos2 = pd.read_csv('aggregation1_2horas.csv')
datos3 = pd.read_csv('aggregation1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)

datos_concatenados.to_csv('1.csv', index=False)

os.remove('aggregation1_2horas.csv')
os.remove('aggregation1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("1.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/1.csv", index=False)

# %% [markdown]
# ### 2- Procesado fichero water_heater.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('water_heater.csv','r') as firstfile, open('./data/ozm1/electricity/8.csv','a') as secondfile: 
with open('water_heater.csv','r') as firstfile, open('water_heater1.csv','a') as secondfile: 
    
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('water_heater1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('water_heater1_2horas.csv', index=False)


datos = pd.read_csv('water_heater1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('water_heater1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('water_heater1.csv')
datos2 = pd.read_csv('water_heater1_2horas.csv')
datos3 = pd.read_csv('water_heater1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('8.csv', index=False)

#borramos ficheros intermedios
os.remove('water_heater1_2horas.csv')
os.remove('water_heater1_4horas.csv')

# %%
#renombramos la columna de timestamp y lo salvamos en la ruta de salida

import pandas as pd
# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("8.csv")
# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})
# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/8.csv", index=False)

# %% [markdown]
# ### 3- Procesado fichero fan.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('fan.csv','r') as firstfile, open('./data/ozm1/electricity/9.csv','a') as secondfile: 
with open('fan.csv','r') as firstfile, open('fan1.csv','a') as secondfile: 
    
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('fan1.csv')
#datos['n'] = datos['n'].astype(str) + str(5818001)    # (2*60*60*1000)
datos['n'] = datos['n'] + 581800    # (2*60*60*1000)

datos.to_csv('fan1_2horas.csv', index=False)


datos = pd.read_csv('fan1.csv')
#datos['n'] = datos['n'].astype(str) + str(5818001*2)  
datos['n'] = datos['n'] + 5818001*2  
datos.to_csv('fan1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('fan1.csv')
datos2 = pd.read_csv('fan1_2horas.csv')
datos3 = pd.read_csv('fan1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('9.csv', index=False)

#borramos ficheros intermedios
#os.remove('fan1_2horas.csv')
#os.remove('fan1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("9.csv",low_memory=False)

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/9.csv", index=False)

# %% [markdown]
# ### 4- Procesado fichero freezer

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('freezer.csv','r') as firstfile, open('./data/ozm1/electricity/11.csv','a') as secondfile: 
with open('freezer.csv','r') as firstfile, open('freezer1.csv','a') as secondfile:     
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('freezer1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('freezer1_2horas.csv', index=False)



datos = pd.read_csv('freezer1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('freezer1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('freezer1.csv')
datos2 = pd.read_csv('freezer1_2horas.csv')
datos3 = pd.read_csv('freezer1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('11.csv', index=False)

#borramos ficheros intermedios
os.remove('freezer1_2horas.csv')
os.remove('freezer1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("11.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/11.csv", index=False)

# %% [markdown]
# ### 5-Procesado fichero monitor.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('monitor.csv','r') as firstfile, open('./data/ozm1/electricity/4.csv','a') as secondfile: 
with open('monitor.csv','r') as firstfile, open('monitor1.csv','a') as secondfile:     
    
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('monitor1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('monitor1_2horas.csv', index=False)


datos = pd.read_csv('monitor1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('monitor1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('monitor1.csv')
datos2 = pd.read_csv('monitor1_2horas.csv')
datos3 = pd.read_csv('monitor1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('4.csv', index=False)

#borramos ficheros intermedios
os.remove('monitor1_2horas.csv')
os.remove('monitor1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("4.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/4.csv", index=False)

# %% [markdown]
# ### 6-Procesado fichero vacuum_cleaner.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('vacuum_cleaner.csv','r') as firstfile, open('./data/ozm1/electricity/6.csv','a') as secondfile: 
with open('vacuum_cleaner.csv','r') as firstfile, open('vacuum_cleaner1.csv','a') as secondfile:     
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('vacuum_cleaner1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('vacuum_cleaner1_2horas.csv', index=False)


datos = pd.read_csv('vacuum_cleaner1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('vacuum_cleaner1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('vacuum_cleaner1.csv')
datos2 = pd.read_csv('vacuum_cleaner1_2horas.csv')
datos3 = pd.read_csv('vacuum_cleaner1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('6.csv', index=False)

#borramos ficheros intermedios
os.remove('vacuum_cleaner1_2horas.csv')
os.remove('vacuum_cleaner1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("6.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/6.csv", index=False)

# %% [markdown]
# ### 7-Procesado fichero kettle.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('kettle.csv','r') as firstfile, open('./data/ozm1/electricity/5.csv','a') as secondfile: 
with open('kettle.csv','r') as firstfile, open('kettle1.csv','a') as secondfile:     
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('kettle1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('kettle1_2horas.csv', index=False)


datos = pd.read_csv('kettle1.csv')
datos['n'] = datos['n'] + (5818001*2)    
datos.to_csv('kettle1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('kettle1.csv')
datos2 = pd.read_csv('kettle1_2horas.csv')
datos3 = pd.read_csv('kettle1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('5.csv', index=False)

#borramos ficheros intermedios
os.remove('kettle1_2horas.csv')
os.remove('kettle1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("5.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/5.csv", index=False)

# %% [markdown]
# ### 8-Procesado fichero fridge.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('fridge.csv','r') as firstfile, open('./data/ozm1/electricity/10.csv','a') as secondfile: 
with open('fridge.csv','r') as firstfile, open('fridge1.csv','a') as secondfile:     
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('fridge1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('fridge1_2horas.csv', index=False)


datos = pd.read_csv('fridge1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('fridge1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('fridge1.csv')
datos2 = pd.read_csv('fridge1_2horas.csv')
datos3 = pd.read_csv('fridge1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('10.csv', index=False)

#borramos ficheros intermedios
os.remove('fridge1_2horas.csv')
os.remove('fridge1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("10.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/10.csv", index=False)

# %% [markdown]
# ### 9-Procesado fichero microwave.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('microwave.csv','r') as firstfile, open('./data/ozm1/electricity/3.csv','a') as secondfile: 
with open('microwave.csv','r') as firstfile, open('microwave1.csv','a') as secondfile:    
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('microwave1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('microwave1_2horas.csv', index=False)


datos = pd.read_csv('microwave1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('microwave1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('microwave1.csv')
datos2 = pd.read_csv('microwave1_2horas.csv')
datos3 = pd.read_csv('microwave1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('3.csv', index=False)

#borramos ficheros intermedios
os.remove('microwave1_2horas.csv')
os.remove('microwave1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("3.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/3.csv", index=False)

# %% [markdown]
# ### 10-Procesado fichero oil_heater.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('oil_heater.csv','r') as firstfile, open('./data/ozm1/electricity/7.csv','a') as secondfile: 
with open('oil_heater.csv','r') as firstfile, open('oil_heater1.csv','a') as secondfile:     
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('oil_heater1.csv')
datos['n'] = str(datos['n']) + 5818001    # (2*60*60*1000)
datos.to_csv('oil_heater1_2horas.csv', index=False)


datos = pd.read_csv('oil_heater1.csv')
datos['n'] = str(datos['n']) + (5818001*2)    
datos.to_csv('oil_heater1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('oil_heater1.csv')
datos2 = pd.read_csv('oil_heater1_2horas.csv')
datos3 = pd.read_csv('oil_heater1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)
#salvamos el resultado
datos_concatenados.to_csv('7.csv', index=False)

#borramos ficheros intermedios
os.remove('oil_heater1_2horas.csv')
os.remove('oil_heater1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("7.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/7.csv", index=False)

# %% [markdown]
# ### 11-Procesado fichero oven.csv

# %%
import re
#copia el contenido de un fichero en otro
OLD= 'timestamp,W,VAR,VA,f,VLN,PF,A,Voltage_Harmonics_Complex,Current_Harmonics_Complex,Power_Harmonics'
NUEVO='n,W,VAR,VA,f,VLN,PF,A,VH1,VH2,VH3,VH4,VH5,VH6,VH7,VH8,VH9,VH10,VH11,VH12,VH13,VH14,VH15,VH16,VH17,VH18,VH19,VH20,VH21,VH22,VH23,VH24,VH25,VH26,VH27,VH28,VH29,VH30,VH31,VH32,VH33,VH34,VH35,VH36,VH37,VH38,VH39,VH40,VH41,VH42,VH43,VH44,VH45,VH46,VH47,VH48,VH49,VH50,IH1,IH2,IH3,IH4,IH5,IH6,IH7,IH8,IH9,IH10,IH11,IH12,IH13,IH14,IH15,IH16,IH17,IH18,IH19,IH20,IH21,IH22,IH23,IH24,IH25,IH26,IH27,IH28,IH29,IH30,IH31,IH32,IH33,IH34,IH35,IH36,IH37,IH38,IH39,IH40,IH41,IH42,IH43,IH44,IH45,IH46,IH47,IH48,IH49,IH50,PH1,PH2,PH3,PH4,PH5,PH6,PH7,PH8,PH9,PH10,PH11,PH12,PH13,PH14,PH15,PH16,PH17,PH18,PH19,PH20,PH21,PH22,PH23,PH24,PH25,PH26,PH27,PH28,PH29,PH30,PH31,PH32,PH33,PH34,PH35,PH36,PH37,PH38,PH39,PH40,PH41,PH42,PH43,PH44,PH45,PH46,PH47,PH48,PH49,PH50'
#with open('oven.csv','r') as firstfile, open('./data/ozm1/electricity/2.csv','a') as secondfile: 
with open('oven.csv','r') as firstfile, open('oven1.csv','a') as secondfile:     
    for line in firstfile: 
        line2=line.replace(OLD,NUEVO)
        line2 = line2.replace('"[', '')
        line2 = line2.replace(']"', '')    
     
      #  print (line2)
        secondfile.write(line2)

# %%
# creamos dos ficheros nuevos con un offset de tiempo        
        
import pandas as pd
import os

datos = pd.read_csv('oven1.csv')
#datos['n'] =datos['n'].astype(str) + 5818001   # (2*60*60*1000)
datos['n'] =datos['n'] + 5818001

datos.to_csv('oven1_2horas.csv', index=False)


datos = pd.read_csv('oven1.csv')
datos['n'] = datos['n'] + 5818001*2    
datos.to_csv('oven1_4horas.csv', index=False)


import pandas as pd
datos1 = pd.read_csv('oven1.csv')
datos2 = pd.read_csv('oven1_2horas.csv')
datos3 = pd.read_csv('oven1_4horas.csv')

datos_concatenados = pd.concat([datos1, datos2,datos3], axis=0)

#salvamos el resultado
datos_concatenados.to_csv('2.csv', index=False)

#borramos ficheros intermedios
#os.remove('oven1_2horas.csv')
#os.remove('oven1_4horas.csv')

# %%
import pandas as pd

# Cargamos el archivo CSV en un DataFrame
df = pd.read_csv("2.csv")

# Renombramos la columna "nombre_antiguo" a "nombre_nuevo"
df = df.rename(columns={"n": "timestamp"})

# Guardamos el DataFrame con el nuevo nombre de la columna en un archivo CSV
df.to_csv("./data/ozm1/electricity/2.csv", index=False)

# %% [markdown]
# ##  manipulacion de csv

# %% [markdown]
# Para 12:47:36, hay 12 horas * 60 minutos/hora * 60 segundos/minuto * 1000 milisegundos/segundo + 47 minutos * 60 segundos/minuto * 1000 milisegundos/segundo + 36 segundos * 1000 milisegundos/segundo = 46056000 milisegundos.
#
# Para 11:10:38, hay 11 horas * 60 minutos/hora * 60 segundos/minuto * 1000 milisegundos/segundo + 10 minutos * 60 segundos/minuto * 1000 milisegundos/segundo + 38 segundos * 1000 milisegundos/segundo = 40238000 milisegundos.
#
# Luego, para calcular la diferencia entre ambas horas, simplemente restamos el número de milisegundos del segundo tiempo al número de milisegundos del primer tiempo:
#
# 46056000 milisegundos - 40238000 milisegundos = 5818000 milisegundos

# %% [markdown]
# The error message "TypeError: can only concatenate str (not 'int') to str" means that you cannot concatenate a string and an integer directly using the '+' operator. To fix this error, you can convert the integer to a string before concatenating it with the string.
#
# In your code, you are trying to concatenate an integer value with a column of strings. You can convert the integer to a string using the str() function and then concatenate it with the string column.
#
# Here's the updated code:
# import pandas as pd
# import os
#
# datos = pd.read_csv('oven1.csv')
# datos['n'] = datos['n'].astype(str) + str(5818001)    # (2*60*60*1000)
# datos.to_csv('oven1_2horas.csv', index=False)
#
# datos = pd.read_csv('oven1.csv')
# print(datos.head())
